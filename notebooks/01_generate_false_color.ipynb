# %% [markdown]
# # Generate false color images

# %%
conda activate cubeglm2
# Out:
# (cubeglm2)
# : 1

# %%
python ../scripts/generate_false_color_batch.py --directory_path="poplar_regen_halogen_a1"
# Out:
# load mode isload_full_then_crop
# /home/gmobot/anaconda3/envs/cubeglm2/lib/python3.8/site-packages/spectral/io/envi.py:175: UserWarning: Parameters with non-lowercase names encountered and converted to lowercase. To retain source file parameter name capitalization, set spectral.settings.envi_support_nonlowercase_params to True.
#   warnings.warn(msg)
# Producing image channel for 533.7419 with cap 563 in color green
# Producing image channel for 563.8288 with cap 904 in color red
# Producing image channel for 500.0404 with cap 406 in color blue
# Saving image to ./poplar_regen_halogen_a1/HAL1_I5.0_F1.9_H25_180516_0_0_0_Broadband_falsecolor.png.png
# Saving image metadata to ./poplar_regen_halogen_a1/HAL1_I5.0_F1.9_H25_180516_0_0_0_Broadband_falsecolor.png.csv
# load mode isload_full_then_crop
# ...
